# %% [markdown]
# # HCI experiment
# Use this jupyter to generate the image stimuli matrix
#
# Goal :
#
#
# Information:
# - EEG sampling = 125 Hz with 16 electrod nodes
#
#
# Requirements:
#
# 1. Genterate represent number 0-9 with 500 number
# 2. Divide it in to 25 blcok, 20 images per block
# 3. Current trial should not same number with previous

# %%
import random
import pylsl
import numpy as np
import pandas as pd
import time
import itertools
import math
import psychopy 
from psychopy import visual, core, event
from datetime import datetime
from IPython.display import clear_output
import random

# %%
#==============================================
# experiment parameters
#==============================================
combination         = 6
task                = 2
classes             = combination * task
num_trial_per_block = 5
num_block           = 15
num_trial           = num_trial_per_block * num_block
total_data_point    = classes * num_trial 

stim_time           = (1, 2)
stim_imagery        = 2
stim_blink_time     = 0
task_flixation_time = (0.8, 1.2)
trial_flixation_time= 2
block_fixation_time = 10  # inter trial interval, i.e., how long the fixation will stay in second


experiment_time  = ( trial_flixation_time + stim_time[-1] + stim_imagery + task_flixation_time[-1] ) * combination * num_trial
print(f"Total experiment time = {'{:.2f}'.format(experiment_time/60)} Minute" )
      
    
#==============================================
# Configuration 
#==============================================
image_folder='./stimulus/large'


#name, type, channel_count, sampling rate, channel format, source_id
#info = StreamInfo('CytonMarkers', 'Markers', 1, 0.0, 'int32', 'CytonMarkerID')#make an outlet
info = pylsl.StreamInfo('CytonMarkers', 'Markers', 1, 0.0, 'string', 'CytonMarkerID')#make an outlet
outlet = pylsl.StreamOutlet(info)
# %whos
# Out:
# Total experiment time = 54.00 Minute

# %%
stims = {
    '1': [1, 2, 3, 4, 5, 6],
    '2': [4, 1, 5, 2 ,6 ,3],
    '3': [5, 3, 1, 6, 4, 2],
    '4': [2, 4, 6, 1, 3, 5],
    '5': [3, 6, 2, 5, 1, 4],
    '6': [6, 5, 4 ,3, 2, 1],
}

# %% [markdown]
# ## Experiment section

# %%
def drawTextOnScreen(massage) :
    message = visual.TextStim( mywin, text=massage, languageStyle='LTR')
    message.contrast =  0.3
    message.height= 0.07
    message.draw() # draw on screen
    mywin.flip()   # refresh to show what we have draw

def drawTrial( fileName, stimTime ) :
    if fileName == 'imagery':
        img = blank
    else:
        img = all_img[fileName-1]
    drawTextOnScreen('') 
    core.wait(stim_blink_time)
    img.draw()
    mywin.flip()
    eegMarking(fileName, "img_stim" )
    core.wait(stimTime)
    
def drawFixation(fileName, fixationTime):
    fixation = visual.ShapeStim(mywin,
                                vertices=((0, -0.5), (0, 0.5), (0,0), (-0.5,0), (0.5, 0)),
                                lineWidth=5,
                                closeShape=False,
                                lineColor="white"
            )
    fixation.draw()
    if not(isTrianing) and fileName == 'rest':
        text = f"Block {block+1} / {num_block}"
        message = visual.TextStim( mywin, text=text, languageStyle='LTR' )
        message.contrast =  0.3
        message.pos = (0, -0.6)
        message.draw() # draw on screen
        
    mywin.flip()   # refresh to show what we have draw
    eegMarking(fileName, "fixation" )
    core.wait(fixationTime)
    drawTextOnScreen('')
     
def eegMarking(img, stampType):   # use trial variable from main
    if not isTrianing :
        if stampType == "img_stim" :
            markerString = str(block+1) + "," + str(trial) + ","  + str(img) + "," + str(timer)
        elif stampType == "fixation" :
            markerString = str(block+1) + "," +str(img) + "," + str("Fixation")
    else:
        markerString = 'Training'
    markerString= str(markerString)                              
    print("Marker string {}".format(markerString))
    outlet.push_sample([markerString])

# %% [markdown]
# ### Stimulies

# %%
trial_idx = 1
wait = 0.5
    
mywin = visual.Window([1366, 768], color='black', fullscr=False, screen=0, units='norm')     # set the screen and full screen mode
# mywin = visual.Window([1920, 1080], color="black", units='norm')    # set the screen and full screen mode

drawTextOnScreen('Loading...')

#Load stimuli to RAM
usefilefname = ['1', '2', '3', '4', '5', '6', 'black']
all_img = []
for im in usefilefname:
    if im == 'black':
        stim = visual.ImageStim( mywin,  image=imgPath )
        stim.size *= .7
        blank = stim
    else:
        imgPath=image_folder+"/"+str(im)+".png"
        stim = visual.ImageStim( mywin,  image=imgPath )
        stim.size *= .7
        all_img.append(stim)

##############
####  Training session
while True:
    isTrianing = True
    drawTextOnScreen('Training session, Press space bar to start')
    keys = event.getKeys()
    if 'space' in keys:      # If space has been pushed
        start = time.time()
        drawTextOnScreen('') 

        trial = 1
        for img in stims[str(np.random.randint(1,6))]:
            drawTextOnScreen(f'Trial {trial}/5')
            core.wait(wait)
            clear_output(wait=True)
            timer = random.choice(stim_time)
            drawFixation('rest', trial_flixation_time-wait)
            drawTrial(img, timer)   # drawTrail(fileName, stimTime, thinkingTime, fixationTime)
            drawFixation('break', np.random.uniform(task_flixation_time[0], task_flixation_time[1]))
            drawTrial('imagery', timer)

            if trial == 5 :
                break
            trial += 1

        drawTextOnScreen('End of training session')
        core.wait(1)
        drawTextOnScreen('You can ask some question to instructure.\nNo? : space bar')
        _ = event.waitKeys()
        isTrianing = False
        break

################
####### Experiment session
play = True
while play:
    drawTextOnScreen('Experiment session : Press space bar to start')
    keys = event.getKeys()
    if 'space' in keys:      # If space has been pushed
        start = time.time()
        drawTextOnScreen('') 

        for block in range(num_block) :
            
            if block % 5 == 0 and block != 0:
                drawTextOnScreen('RELAX TIME\n*Do not remove your head set\nPress space. bar to continue')
                _ = event.waitKeys()
                
            for trial in range(num_trial_per_block):
                for img in stims[str(trial_idx)]:
                    drawTextOnScreen(f'Trial {trial+1}/{num_trial_per_block}')
                    core.wait(wait)
                    clear_output(wait=True)
                    timer = random.choice(stim_time)
                    drawFixation('trial break', trial_flixation_time-wait)
                    drawTrial(img, timer)   # drawTrail(fileName, stimTime, thinkingTime, fixationTime)
                    drawFixation('task break', np.random.uniform(task_flixation_time[0], task_flixation_time[1]))
                    drawTrial('imagery', timer)

            if block != num_block:  # do not draw fixation on last block
                drawTextOnScreen(f'BLOCK REST\n {block_fixation_time} sec.')
                core.wait(block_fixation_time)

        drawTextOnScreen('End of experiment, Thank you')
        stop  = time.time()
        print(f"Total experiment time = {(stop-start)/60} ")
        core.wait(10)
        play = False

mywin.close()
core.quit()
# Out:
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7553a714938c> in <module>
#      27 while True:
#      28     isTrianing = True
# ---> 29     drawTextOnScreen('Training session, Press space bar to start')
#      30     keys = event.getKeys()
#      31     if 'space' in keys:      # If space has been pushed
#
# <ipython-input-4-2faffdfad3e4> in drawTextOnScreen(massage)
#       1 def drawTextOnScreen(massage) :
# ----> 2     message = visual.TextStim( mywin, text=massage, languageStyle='LTR')
#       3     message.contrast =  0.3
#       4     message.height= 0.07
#       5     message.draw() # draw on screen
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psychopy/visual/text.py in __init__(self, win, text, font, pos, depth, rgb, color, colorSpace, opacity, contrast, units, ori, height, antialias, bold, italic, alignHoriz, alignVert, alignText, anchorHoriz, anchorVert, fontFiles, wrapWidth, flipHoriz, flipVert, languageStyle, name, autoLog)
#     231         self.__dict__['autoLog'] = autoLog or wantLog
#     232         if self.autoLog:
# --> 233             logging.exp("Created %s = %s" % (self.name, str(self)))
#     234
#     235     def __del__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psychopy/visual/basevisual.py in __str__(self, complete)
#     111                 if hasattr(self, param):
#     112                     val = getattr(self, param)
# --> 113                     valStr = repr(getattr(self, param))
#     114                     if len(repr(valStr)) > 50 and not complete:
#     115                         if val.__class__.__name__ == 'attributeSetter':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in _array_repr_implementation(arr, max_line_width, precision, suppress_small, array2string)
#    1384         lst = repr(arr.item())
#    1385     elif arr.size > 0 or arr.shape == (0,):
# -> 1386         lst = array2string(arr, max_line_width, precision, suppress_small,
#    1387                            ', ', prefix, suffix=suffix)
#    1388     else:  # show zero-length shape unless it is (0,)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     690         return "[]"
#     691
# --> 692     return _array2string(a, options, separator, prefix)
#     693
#     694
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in wrapper(self, *args, **kwargs)
#     466             repr_running.add(key)
#     467             try:
# --> 468                 return f(self, *args, **kwargs)
#     469             finally:
#     470                 repr_running.discard(key)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in _array2string(a, options, separator, prefix)
#     492
#     493     # find the right formatting function for the array
# --> 494     format_function = _get_format_function(data, **options)
#     495
#     496     # skip over "["
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in _get_format_function(data, **options)
#     425             return formatdict['longfloat']()
#     426         else:
# --> 427             return formatdict['float']()
#     428     elif issubclass(dtypeobj, _nt.complexfloating):
#     429         if issubclass(dtypeobj, _nt.clongfloat):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in <lambda>()
#     364         'bool': lambda: BoolFormat(data),
#     365         'int': lambda: IntegerFormat(data),
# --> 366         'float': lambda: FloatingFormat(
#     367             data, precision, floatmode, suppress, sign, legacy=legacy),
#     368         'longfloat': lambda: FloatingFormat(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in __init__(self, data, precision, floatmode, suppress_small, sign, legacy)
#     859         self.large_exponent = False
#     860
# --> 861         self.fillFormat(data)
#     862
#     863     def fillFormat(self, data):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in fillFormat(self, data)
#     868         abs_non_zero = absolute(finite_vals[finite_vals != 0])
#     869         if len(abs_non_zero) != 0:
# --> 870             max_val = np.max(abs_non_zero)
#     871             min_val = np.min(abs_non_zero)
#     872             with errstate(over='ignore'):  # division can overflow
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2703     5
#    2704     """
# -> 2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2706                           keepdims=keepdims, initial=initial, where=where)
#    2707
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %%
mywin.close()
core.quit()
